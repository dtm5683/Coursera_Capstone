# %% [markdown]
# ## **Segmenting and Clustering Neighborhoods in Toronto**

# %%
# !pip install geocoder

# %%
import pandas as pd
import numpy as np
import requests
import geocoder
import folium
import matplotlib.pyplot as plt

# %%
wiki_url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %% [markdown]
# Use pandas to get the tables from the site

# %%
web_table = pd.read_html(wiki_url, header=0)

# %% [markdown]
# Takes the table in index 0

# %%
df = pd.DataFrame(web_table[0])
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Remove Borough values with "Not assigned" values

# %%
can_data = df[df['Borough']!='Not assigned']
print(can_data.head())
print(can_data.shape)
can_data = can_data.reset_index()
can_data = can_data.drop('index', axis=1)
can_data.head(5)
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# (103, 3)
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
print(len(can_data))
print(can_data['Postal Code'].unique)
# Out:
# 103
# <bound method Series.unique of 0      M3A
# 1      M4A
# 2      M5A
# 3      M6A
# 4      M7A
#       ...
# 98     M8X
# 99     M4Y
# 100    M7Y
# 101    M8Y
# 102    M8Z
# Name: Postal Code, Length: 103, dtype: object>

# %% [markdown]
# Confirming the data is in the correct format. M5A postal cost is listed once and includes the 2 neighborhoods

# %%
print(can_data.query("`Postal Code` == 'M5A'"))
# Out:
#   Postal Code           Borough              Neighbourhood
# 2         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
final_cd.shape
# Out:
# (103, 3)

# %% [markdown]
# Append the Latitude and Longitude for the entries

# %%
# get the geolocations
geo_csv = "https://cocl.us/Geospatial_data"
df_geo = pd.read_csv(geo_csv)

df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Merge the 2 data frames bases on the postal code

# %%
merged_df = can_data.merge(df_geo, how='left', left_on='Postal Code', right_on='Postal Code')
print(merged_df.head())
print(merged_df.shape)
# Out:
#   Postal Code           Borough  ...   Latitude  Longitude
# 0         M3A        North York  ...  43.753259 -79.329656
# 1         M4A        North York  ...  43.725882 -79.315572
# 2         M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3         M6A        North York  ...  43.718518 -79.464763
# 4         M7A  Downtown Toronto  ...  43.662301 -79.389494
#
# [5 rows x 5 columns]
# (103, 5)

# %%
print(merged_df.columns) # confirmed all the columns are available.
# Out:
# Index(['Postal Code', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude'], dtype='object')

# %% [markdown]
# Visualise the neighborhoods in Toronto

# %%
# get the latitude and longitude for Toronto

address = 'Toronto, Toronto'
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6534817, -79.3839347.

# %%
# create the map of Toronto
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers
for lat, lng, label in zip(merged_df['Latitude'], merged_df['Longitude'], merged_df['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Map for Downtown Toronto Neighbourhoods

# %%
# create DF for Toronto
toronto_df = merged_df.query("Borough =='Downtown Toronto'")
print(toronto_df.head())
# Out:
#    Postal Code           Borough  ...   Latitude  Longitude
# 2          M5A  Downtown Toronto  ...  43.654260 -79.360636
# 4          M7A  Downtown Toronto  ...  43.662301 -79.389494
# 9          M5B  Downtown Toronto  ...  43.657162 -79.378937
# 15         M5C  Downtown Toronto  ...  43.651494 -79.375418
# 20         M5E  Downtown Toronto  ...  43.644771 -79.373306
#
# [5 rows x 5 columns]

# %%
# create the map of Toronto
map_dt_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dt_toronto)  
    
map_dt_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# FourSquare Credentials

CLIENT_ID = 'YRUQY0JGVLGJXENFNXELCMVQZAGG0SDC54GHW2SPCZI1SLQY' # Foursquare ID
CLIENT_SECRET = '3C210CKZBHWVQN3BZCEM3YB5VRYLHXLEBGJLFF2KHFMIBXNI' # Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YRUQY0JGVLGJXENFNXELCMVQZAGG0SDC54GHW2SPCZI1SLQY
# CLIENT_SECRET:3C210CKZBHWVQN3BZCEM3YB5VRYLHXLEBGJLFF2KHFMIBXNI

# %%
# function to retrieve FourSquare API

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_df['Neighbourhood'],
                                   latitudes=toronto_df['Latitude'],
                                   longitudes=toronto_df['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (796, 7)
#                 Neighborhood  ...       Venue Category
# 0  Regent Park, Harbourfront  ...               Bakery
# 1  Regent Park, Harbourfront  ...          Coffee Shop
# 2  Regent Park, Harbourfront  ...  Distribution Center
# 3  Regent Park, Harbourfront  ...                  Spa
# 4  Regent Park, Harbourfront  ...           Restaurant
#
# [5 rows x 7 columns]

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Berczy Park                                                            50  ...              50
# CN Tower, King and Spadina, Railway Lands, Harb...                     16  ...              16
# Central Bay Street                                                     50  ...              50
# Christie                                                               17  ...              17
# Church and Wellesley                                                   50  ...              50
# Commerce Court, Victoria Hotel                                         50  ...              50
# First Canadian Place, Underground city                                 50  ...              50
# Garden District, Ryerson                                               50  ...              50
# Harbourfront East, Union Station, Toronto Islands                      50  ...              50
# Kensington Market, Chinatown, Grange Park                              50  ...              50
# Queen's Park, Ontario Provincial Government                            36  ...              36
# Regent Park, Harbourfront                                              44  ...              44
# Richmond, Adelaide, King                                               50  ...              50
# Rosedale                                                                4  ...               4
# St. James Town                                                         50  ...              50
# St. James Town, Cabbagetown                                            45  ...              45
# Stn A PO Boxes                                                         50  ...              50
# Toronto Dominion Centre, Design Exchange                               50  ...              50
# University of Toronto, Harbord                                         34  ...              34
#
# [19 rows x 6 columns]

# %%
# number of unique categories.

print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 179 uniques categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
col_list = list(toronto_onehot.columns)
col_list.remove('Neighborhood')
cols = ['Neighborhood'] + [col for col in col_list]

toronto_onehot = toronto_onehot[cols]
toronto_onehot.head()
# Out:
#                 Neighborhood  Airport  ...  Wine Bar  Yoga Studio
# 0  Regent Park, Harbourfront        0  ...         0            0
# 1  Regent Park, Harbourfront        0  ...         0            0
# 2  Regent Park, Harbourfront        0  ...         0            0
# 3  Regent Park, Harbourfront        0  ...         0            0
# 4  Regent Park, Harbourfront        0  ...         0            0
#
# [5 rows x 179 columns]

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()
# Out:
#                                         Neighborhood  ...  Yoga Studio
# 0                                        Berczy Park  ...         0.00
# 1  CN Tower, King and Spadina, Railway Lands, Har...  ...         0.00
# 2                                 Central Bay Street  ...         0.02
# 3                                           Christie  ...         0.00
# 4                               Church and Wellesley  ...         0.04
#
# [5 rows x 179 columns]

# %%
from sklearn.cluster import KMeans

kclusters = 5

# drop neighbourhood
toronto_grouped_clustering = toronto_grouped.drop(['Neighborhood'], axis=1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 3, 0, 4, 2, 2, 2, 2, 2, 2], dtype=int32)

# %%
len(kmeans.labels_)
# Out:
# 19

# %%
# add clustering labels
toronto_grouped.insert(0, 'Cluster Labels', kmeans.labels_)
print(toronto_grouped.head())

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_grouped_merged = toronto_grouped.merge(toronto_venues, how='left', left_on='Neighborhood', right_on='Neighborhood')
print(toronto_grouped_merged.head())
# Out:
#    Cluster Labels Neighborhood  ...  Venue Longitude                 Venue Category
# 0               2  Berczy Park  ...       -79.374768                     Restaurant
# 1               2  Berczy Park  ...       -79.372440                   Liquor Store
# 2               2  Berczy Park  ...       -79.374453  Vegetarian / Vegan Restaurant
# 3               2  Berczy Park  ...       -79.376022                   Concert Hall
# 4               2  Berczy Park  ...       -79.373541                       Beer Bar
#
# [5 rows x 186 columns]

# %%
toronto_grouped_merged.head()
# Out:
#    Cluster Labels Neighborhood  ...  Venue Longitude                 Venue Category
# 0               2  Berczy Park  ...       -79.374768                     Restaurant
# 1               2  Berczy Park  ...       -79.372440                   Liquor Store
# 2               2  Berczy Park  ...       -79.374453  Vegetarian / Vegan Restaurant
# 3               2  Berczy Park  ...       -79.376022                   Concert Hall
# 4               2  Berczy Park  ...       -79.373541                       Beer Bar
#
# [5 rows x 186 columns]

# %%
# visualise the results of clustering
import matplotlib.cm as cm
import matplotlib.colors as colors
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_grouped_merged['Neighborhood Latitude'], toronto_grouped_merged['Neighborhood Longitude'], toronto_grouped_merged['Neighborhood'], toronto_grouped_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Look at each cluster a bit closer

# %%
toronto_grouped_merged.loc[toronto_grouped_merged['Cluster Labels'] == 0, toronto_grouped_merged.columns[[1] + list(range(5, toronto_grouped_merged.shape[1]))]]
# Out:
#                   Neighborhood  ...             Venue Category
# 66          Central Bay Street  ...                Coffee Shop
# 67          Central Bay Street  ...                Coffee Shop
# 68          Central Bay Street  ...  Middle Eastern Restaurant
# 69          Central Bay Street  ...                Coffee Shop
# 70          Central Bay Street  ...                Coffee Shop
# ..                         ...  ...                        ...
# 508  Regent Park, Harbourfront  ...                       Bank
# 509  Regent Park, Harbourfront  ...                Coffee Shop
# 510  Regent Park, Harbourfront  ...                 Beer Store
# 511  Regent Park, Harbourfront  ...                      Hotel
# 512  Regent Park, Harbourfront  ...               Antique Shop
#
# [130 rows x 182 columns]

# %%
toronto_grouped_merged.loc[toronto_grouped_merged['Cluster Labels'] == 1, toronto_grouped_merged.columns[[1] + list(range(5, toronto_grouped_merged.shape[1]))]]
# Out:
#     Neighborhood  Airport Lounge  ...  Venue Longitude  Venue Category
# 563     Rosedale             0.0  ...       -79.378934      Playground
# 564     Rosedale             0.0  ...       -79.373788            Park
# 565     Rosedale             0.0  ...       -79.382773            Park
# 566     Rosedale             0.0  ...       -79.373842           Trail
#
# [4 rows x 182 columns]

# %%
toronto_grouped_merged.loc[toronto_grouped_merged['Cluster Labels'] == 2, toronto_grouped_merged.columns[[1] + list(range(5, toronto_grouped_merged.shape[1]))]]
# Out:
#                        Neighborhood  ...                 Venue Category
# 0                       Berczy Park  ...                     Restaurant
# 1                       Berczy Park  ...                   Liquor Store
# 2                       Berczy Park  ...  Vegetarian / Vegan Restaurant
# 3                       Berczy Park  ...                   Concert Hall
# 4                       Berczy Park  ...                       Beer Bar
# ..                              ...  ...                            ...
# 791  University of Toronto, Harbord  ...                           Café
# 792  University of Toronto, Harbord  ...                   Noodle House
# 793  University of Toronto, Harbord  ...                      Nightclub
# 794  University of Toronto, Harbord  ...                     Beer Store
# 795  University of Toronto, Harbord  ...                            Pub
#
# [629 rows x 182 columns]

# %%
toronto_grouped_merged.loc[toronto_grouped_merged['Cluster Labels'] == 3, toronto_grouped_merged.columns[[1] + list(range(5, toronto_grouped_merged.shape[1]))]]
# Out:
#                                          Neighborhood  ...       Venue Category
# 50  CN Tower, King and Spadina, Railway Lands, Har...  ...              Airport
# 51  CN Tower, King and Spadina, Railway Lands, Har...  ...       Airport Lounge
# 52  CN Tower, King and Spadina, Railway Lands, Har...  ...      Harbor / Marina
# 53  CN Tower, King and Spadina, Railway Lands, Har...  ...   Airport Food Court
# 54  CN Tower, King and Spadina, Railway Lands, Har...  ...     Airport Terminal
# 55  CN Tower, King and Spadina, Railway Lands, Har...  ...         Airport Gate
# 56  CN Tower, King and Spadina, Railway Lands, Har...  ...          Coffee Shop
# 57  CN Tower, King and Spadina, Railway Lands, Har...  ...                  Bar
# 58  CN Tower, King and Spadina, Railway Lands, Har...  ...       Airport Lounge
# 59  CN Tower, King and Spadina, Railway Lands, Har...  ...      Airport Service
# 60  CN Tower, King and Spadina, Railway Lands, Har...  ...  Rental Car Location
# 61  CN Tower, King and Spadina, Railway Lands, Har...  ...     Airport Terminal
# 62  CN Tower, King and Spadina, Railway Lands, Har...  ...      Airport Service
# 63  CN Tower, King and Spadina, Railway Lands, Har...  ...      Airport Service
# 64  CN Tower, King and Spadina, Railway Lands, Har...  ...     Sculpture Garden
# 65  CN Tower, King and Spadina, Railway Lands, Har...  ...        Boat or Ferry
#
# [16 rows x 182 columns]

# %%
toronto_grouped_merged.loc[toronto_grouped_merged['Cluster Labels'] == 4, toronto_grouped_merged.columns[[1] + list(range(5, toronto_grouped_merged.shape[1]))]]
# Out:
#     Neighborhood  Airport Lounge  ...  Venue Longitude      Venue Category
# 116     Christie             0.0  ...       -79.420485       Grocery Store
# 117     Christie             0.0  ...       -79.426105                Café
# 118     Christie             0.0  ...       -79.421400         Coffee Shop
# 119     Christie             0.0  ...       -79.426148  Italian Restaurant
# 120     Christie             0.0  ...       -79.419938                Café
# 121     Christie             0.0  ...       -79.426541               Diner
# 122     Christie             0.0  ...       -79.428054          Restaurant
# 123     Christie             0.0  ...       -79.421289         Candy Store
# 124     Christie             0.0  ...       -79.421364       Grocery Store
# 125     Christie             0.0  ...       -79.419297                Café
# 126     Christie             0.0  ...       -79.427573       Grocery Store
# 127     Christie             0.0  ...       -79.420499          Baby Store
# 128     Christie             0.0  ...       -79.426611           Nightclub
# 129     Christie             0.0  ...       -79.418106  Athletics & Sports
# 130     Christie             0.0  ...       -79.423988                Park
# 131     Christie             0.0  ...       -79.427805                Park
# 132     Christie             0.0  ...       -79.428217       Grocery Store
#
# [17 rows x 182 columns]

# %%
print(len(toronto_grouped_merged))
# Out:
# 796
